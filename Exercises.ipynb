# %% [markdown]
# # Exercise 1 - Import Pandas library

# %%
# Put your anwser here

# %% [markdown]
# # Exercise 2 - Read CSV file into Pandas DataFrame

# %%
# Put your anwser here

# %%
# Out:
#           RECORD_NBR  PAY_YEAR  DEPARTMENT_NO     DEPARTMENT_TITLE  \
# 0       303030303632      2017             98      WATER AND POWER
# 1         3030303036      2017             98      WATER AND POWER
# 2       303030313232      2017             98      WATER AND POWER
# 3       303030313632      2017             98      WATER AND POWER
# 4       303030323632      2017             98      WATER AND POWER
# ...              ...       ...            ...                  ...
# 685456  393936353833      2022             43  LOS ANGELES HOUSING
# 685457    3939393534      2022             42               HARBOR
# 685458    3939393535      2022              4             AIRPORTS
# 685459  393939353733      2022             70               POLICE
# 685460  393939353933      2022             70               POLICE
#
#        JOB_CLASS_PGRADE               JOB_TITLE EMPLOYMENT_TYPE JOB_STATUS  \
# 0                3156-5               CUSTODIAN       FULL_TIME     ACTIVE
# ...

# %% [markdown]
# # Exercise 3 - Inspect Data Structure

# %%
# Put your anwser here

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 685461 entries, 0 to 685460
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   RECORD_NBR                     685461 non-null  string
#  1   PAY_YEAR                       685461 non-null  int64
#  2   DEPARTMENT_NO                  685461 non-null  int64
#  3   DEPARTMENT_TITLE               685461 non-null  object
#  4   JOB_CLASS_PGRADE               684919 non-null  object
#  5   JOB_TITLE                      684919 non-null  object
#  6   EMPLOYMENT_TYPE                685461 non-null  object
#  7   JOB_STATUS                     685461 non-null  object
#  8   MOU                            684777 non-null  string
#  9   MOU_TITLE                      684712 non-null  object
#  10  REGULAR_PAY                    685461 non-null  float64
#  11  OVERTIME_PAY                   685027 non-null  float64
# ...

# %% [markdown]
# # Exercise 4 - Explore Data

# %%
# Put your anwser here

# %%
# Out:
#      RECORD_NBR  PAY_YEAR  DEPARTMENT_NO DEPARTMENT_TITLE JOB_CLASS_PGRADE  \
# 0  303030303632      2017             98  WATER AND POWER           3156-5
# 1    3030303036      2017             98  WATER AND POWER           9105-5
# 2  303030313232      2017             98  WATER AND POWER           9602-4
# 3  303030313632      2017             98  WATER AND POWER           5885-5
# 4  303030323632      2017             98  WATER AND POWER           3841-5
#
#                 JOB_TITLE EMPLOYMENT_TYPE JOB_STATUS MOU  \
# 0               CUSTODIAN       FULL_TIME     ACTIVE   8
# 1   UTILITY ADMINISTRATOR       FULL_TIME     ACTIVE   M
# 2  WATER SERVICES MANAGER       FULL_TIME     ACTIVE   M
# 3           WTR TRTMT OPR       FULL_TIME     ACTIVE   6
# 4               ELTL MCHC       FULL_TIME     ACTIVE   8
#
#                                 MOU_TITLE  REGULAR_PAY  OVERTIME_PAY  \
# 0  OPERATING MAINTENANCE AND SERVICE UNIT     55725.24       4785.05
# ...

# %% [markdown]
# # Exercise 5 - Select specific columns - Pay Year, Department, Job Status, Job Title, Total Pay

# %%
# Put your anwser here

# %%
# Out:
#         PAY_YEAR     DEPARTMENT_TITLE JOB_STATUS               JOB_TITLE  \
# 0           2017      WATER AND POWER     ACTIVE               CUSTODIAN
# 1           2017      WATER AND POWER     ACTIVE   UTILITY ADMINISTRATOR
# 2           2017      WATER AND POWER     ACTIVE  WATER SERVICES MANAGER
# 3           2017      WATER AND POWER     ACTIVE           WTR TRTMT OPR
# 4           2017      WATER AND POWER     ACTIVE               ELTL MCHC
# ...          ...                  ...        ...                     ...
# 685456      2022  LOS ANGELES HOUSING     ACTIVE        ACCOUNTING CLERK
# 685457      2022               HARBOR     ACTIVE   SENIOR CIVIL ENGINEER
# 685458      2022             AIRPORTS     ACTIVE        SECURITY OFFICER
# 685459      2022               POLICE     ACTIVE       POLICE OFFICER II
# 685460      2022               POLICE     ACTIVE      EQUIPMENT MECHANIC
#
#         TOTAL_PAY
# 0        62532.13
# 1       161685.87
# 2       258383.42
# ...

# %% [markdown]
# # Exercise 6 - List out all departments and get record count for each department

# %%
# Put your anwser here

# %%
# Out:
# POLICE                                                          150016
# WATER AND POWER                                                 109906
# RECREATION AND PARKS                                             92359
# AIRPORTS                                                         42762
# FIRE                                                             42294
# PUBLIC WORKS - SANITATION                                        35867
# TRANSPORTATION                                                   23149
# GENERAL SERVICES                                                 21103
# LIBRARY                                                          18086
# HARBOR                                                           13819
# PUBLIC WORKS - STREET SERVICES                                   13246
# CITY ATTORNEY                                                    12340
# BUILDING AND SAFETY                                              12163
# ...

# %% [markdown]
# # Exercise 7 - Get the top 5 departments with the most record count

# %%
# Put your anwser here

# %%
# Out:
# POLICE                  150016
# WATER AND POWER         109906
# RECREATION AND PARKS     92359
# AIRPORTS                 42762
# FIRE                     42294
# Name: DEPARTMENT_TITLE, dtype: int64

# %% [markdown]
# # Exercise 8 - Retrieve records by row position

# %%
# Put your anwser here

# %%
# Out:
#    index    RECORD_NBR  PAY_YEAR  DEPARTMENT_NO DEPARTMENT_TITLE  \
# 2      2  303030313232      2017             98  WATER AND POWER
# 3      3  303030313632      2017             98  WATER AND POWER
# 4      4  303030323632      2017             98  WATER AND POWER
#
#   JOB_CLASS_PGRADE               JOB_TITLE EMPLOYMENT_TYPE JOB_STATUS MOU  \
# 2           9602-4  WATER SERVICES MANAGER       FULL_TIME     ACTIVE   M
# 3           5885-5           WTR TRTMT OPR       FULL_TIME     ACTIVE   6
# 4           3841-5               ELTL MCHC       FULL_TIME     ACTIVE   8
#
#                                 MOU_TITLE  REGULAR_PAY  OVERTIME_PAY  \
# 2               MANAGEMENT EMPLOYEES UNIT    245879.12          0.00
# 3       STEAM PLANT AND WATER SUPPLY UNIT    101494.34       7824.99
# 4  OPERATING MAINTENANCE AND SERVICE UNIT    101345.12      22284.37
#
#    ALL_OTHER_PAY  TOTAL_PAY  CITY_RETIREMENT_CONTRIBUTIONS  BENEFIT_PAY  \
# ...

# %% [markdown]
# # Exercise 9 - Retrieve record by index key

# %%
# Put your anwser here

# %%
# Out:
#         RECORD_NBR  PAY_YEAR  JOB_STATUS DEPARTMENT_TITLE  \
# 113172  3937353837      2013  NOT_ACTIVE    CITY ATTORNEY
# 636310  3937353837      2021      ACTIVE    CITY ATTORNEY
# 562981  3937353837      2019      ACTIVE    CITY ATTORNEY
# 531200  3937353837      2016  NOT_ACTIVE    CITY ATTORNEY
# 531199  3937353837      2016  NOT_ACTIVE    CITY ATTORNEY
# 440685  3937353837      2018      ACTIVE    CITY ATTORNEY
# 685455  3937353837      2022      ACTIVE    CITY ATTORNEY
# 274247  3937353837      2017      ACTIVE    CITY ATTORNEY
# 274246  3937353837      2017  NOT_ACTIVE    CITY ATTORNEY
# 411129  3937353837      2020      ACTIVE    CITY ATTORNEY
# 223480  3937353837      2015  NOT_ACTIVE    CITY ATTORNEY
# 113173  3937353837      2013  NOT_ACTIVE    CITY ATTORNEY
# 166799  3937353837      2014  NOT_ACTIVE    CITY ATTORNEY
# 166800  3937353837      2014  NOT_ACTIVE    CITY ATTORNEY
# 166798  3937353837      2014  NOT_ACTIVE    CITY ATTORNEY
# ...

# %% [markdown]
# # Exercise 10 - Retrieve all Active Job in Year 2020 with Total Pay > 300,000

# %%
# Put your anwser here

# %%
# Out:
#           RECORD_NBR   index  PAY_YEAR  DEPARTMENT_NO DEPARTMENT_TITLE  \
# 327190  303137373133  327190      2020             38             FIRE
# 327549    3431323137  327549      2020             38             FIRE
# 327674    3537323833  327674      2020             70           POLICE
# 328221    3030363434  328221      2020             38             FIRE
# 328363    3030383632  328363      2020             38             FIRE
# ...              ...     ...       ...            ...              ...
# 600742  393633333532  600742      2020             98  WATER AND POWER
# 600812  393639353133  600812      2020             98  WATER AND POWER
# 600840  393732373532  600840      2020             98  WATER AND POWER
# 600951  393834323632  600951      2020             98  WATER AND POWER
# 601028    3939323932  601028      2020             98  WATER AND POWER
#
#        JOB_CLASS_PGRADE                       JOB_TITLE EMPLOYMENT_TYPE  \
# ...

# %% [markdown]
# # Exercise 11 - Get active job record count of Fire and Police Department

# %%
# Put your anwser here

# %%
# Out:
# POLICE    92067
# FIRE      26776
# Name: DEPARTMENT_TITLE, dtype: int64

# %% [markdown]
# # Exercise 12 - Get the average total pay of active job in 2021

# %%
# Put your anwser here

# %%
payroll[(payroll["JOB_STATUS"] == "ACTIVE") & (payroll["PAY_YEAR"] == 2021)]["TOTAL_PAY"].mean()
# Out:
# 92887.01988448336

# %% [markdown]
# # Exercise 13 - Which active job got the highest total pay in 2021?

# %%
# Put your anwser here

# %%
# Out:
#         RECORD_NBR   index  PAY_YEAR  DEPARTMENT_NO DEPARTMENT_TITLE  \
# 324821  3437303233  324821      2021             38             FIRE
#
#        JOB_CLASS_PGRADE       JOB_TITLE EMPLOYMENT_TYPE JOB_STATUS MOU  \
# 324821           2142-1  FIRE CAPTAIN I       FULL_TIME     ACTIVE  23
#
#                              MOU_TITLE  REGULAR_PAY  OVERTIME_PAY  \
# 324821  FIREFIGHTERS AND FIRE CAPTAINS     160451.2     420054.86
#
#         ALL_OTHER_PAY  TOTAL_PAY  CITY_RETIREMENT_CONTRIBUTIONS  BENEFIT_PAY  \
# 324821         1686.0  582192.06                       75171.39      11121.6
#
#        GENDER ETHNICITY
# 324821   MALE     BLACK

# %% [markdown]
# # Exercise 14 - List out the average of total pay between male and female for each department

# %%
# Put your anwser here

# %%
# Out:
# DEPARTMENT_TITLE              GENDER
# AGING                         FEMALE     17152.026521
#                               MALE       20824.169747
# AIRPORTS                      FEMALE     60382.733712
#                               MALE       77559.839284
# ANIMAL SERVICES               FEMALE     49005.644082
#                                             ...
# WATER AND POWER               MALE      113282.815733
# YOUTH DEVELOPMENT DEPARTMENT  FEMALE     22295.524000
#                               MALE       53524.700000
# ZOO                           FEMALE     33864.337534
#                               MALE       42402.344986
# Name: TOTAL_PAY, Length: 112, dtype: float64

# %% [markdown]
# # Exercise 15 - Show average total pay of each year (column) by department (row)

# %%
# Put your anwser here

# %%
# Out:
# PAY_YEAR                                                     2013  \
# DEPARTMENT_TITLE
# AGING                                                17464.298583
# AIRPORTS                                             74057.612162
# ANIMAL SERVICES                                      54110.481597
# BUILDING AND SAFETY                                  79798.501172
# CANNABIS REGULATION                                           NaN
# CITY ADMINISTRATIVE OFFICER                          71144.444364
# CITY ATTORNEY                                        95153.155934
# CITY CLERK                                            5114.196060
# CITY EMPLOYEES RETIREMENT SYSTEM                     56331.472587
# CITY ETHICS COMMISSION                               66821.040645
# CITY PLANNING                                        69507.794277
# CIVIL, HUMAN RIGHTS AND EQUITY DEPARTMENT                     NaN
# COLISEUM/SPORTS ARENA                                37559.696944
# ...
